# %% [markdown]
# <a href="https://colab.research.google.com/github/electrojam/Curso-de-Python-para-Ciencia-de-Datos/blob/main/Clase26_Gr%C3%A1ficos_de_Histograma_y_Boxplot_para_distribuciones26_32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Creamos array con datos aleatorios con distribución normal
# Datos de alturas de personas
# con una media = 170, std = 10 , 200 datos.

data = np.random.normal(170, 10, 200)
print(data)
# Out:
# [180.12514667 180.13235146 165.05224749 168.57077778 177.8575542
#  162.86806732 159.76386092 179.10966337 159.44697403 169.0559402
#  171.02840762 156.52854969 161.39828153 167.35503274 177.92219875
#  164.60585526 165.69250864 172.1912005  172.58680261 156.54816293
#  186.76657968 177.22383446 144.4947402  188.09900052 167.81406912
#  182.85906665 170.90079796 181.44520178 161.69610928 182.1978898
#  183.18078437 182.7629497  167.1320323  181.96662436 165.08446882
#  179.16245112 182.7316272  189.12450814 173.16425438 175.74367438
#  162.17893984 156.99006417 176.16236297 170.67035743 178.30808991
#  179.95857895 170.48967193 165.07730219 165.97863989 191.40426295
#  185.02122986 166.59279336 176.36831308 188.21592859 170.77330213
#  166.05430272 181.59809668 152.28998336 155.37967203 177.01267233
#  177.63792549 189.89210055 190.12081121 181.16225295 174.2820895
#  170.09422892 161.97908018 180.80754654 176.17174063 167.41615368
# ...

# %%
# Graficamos histrogram de data

# Creamos el gráfico histograma
plt.hist(data, color='salmon', edgecolor='black', alpha=0.6)

# Etiquetamos
plt.title('Distribución de alturas de personas')
plt.xlabel('Altura (cm)')
plt.ylabel('Densidad')

# Mostramos el gráfico
plt.show()

# %%
# Modificamos divisiones, número de intervalos del gráfico histograma

# Creamos el gráfico histograma
plt.hist(data, color='salmon', edgecolor='black', alpha=0.6, bins=20)

# Etiquetamos
plt.title('Distribución de alturas de personas')
plt.xlabel('Altura (cm)')
plt.ylabel('Densidad')

# Mostramos el gráfico
plt.show()

# %%
# Gráfico de Boxplot

# Extablecer una semilla de inicio
# para que no cambie la data cada que se ejecute
np.random.seed(0)

# Crear lista con 3 arrays con información de rango de edades
ages = [np.random.normal(30, 5, 100),
        np.random.normal(40, 5, 100),
        np.random.normal(35, 5, 100)]

print(ages)
# Out:
# [array([38.82026173, 32.00078604, 34.89368992, 41.204466  , 39.33778995,
#        25.1136106 , 34.75044209, 29.24321396, 29.48390574, 32.05299251,
#        30.72021786, 37.27136753, 33.80518863, 30.60837508, 32.21931616,
#        31.66837164, 37.47039537, 28.97420868, 31.56533851, 25.7295213 ,
#        17.23505092, 33.26809298, 34.32218099, 26.2891749 , 41.34877312,
#        22.72817163, 30.22879259, 29.06408075, 37.66389607, 37.34679385,
#        30.77473713, 31.8908126 , 25.56107126, 20.09601766, 28.26043925,
#        30.78174485, 36.1514534 , 36.01189924, 28.06336591, 28.48848625,
#        24.75723517, 22.89991031, 21.46864905, 39.75387698, 27.45173909,
#        27.80962849, 23.7360232 , 33.88745178, 21.93051076, 28.9362986 ,
#        25.52266719, 31.93451249, 27.44597431, 24.09683908, 29.85908886,
#        32.14165935, 30.33258611, 31.51235949, 26.82838953, 28.18629417,
#        26.63769776, 28.20223419, 25.93426859, 21.36858699, 30.88713071,
# ...

# %%
# Creamos gráfico Boxplot con los 3 datas
plt.boxplot(ages, patch_artist=True, notch=True, vert=True, labels=['Grupo', 'Grupo 2', 'Grupo 3'])

# Etiquetamos el gráfico
plt.title('Distribución de edades por grupo')
plt.xlabel('Grupo')
plt.ylabel('Edad (años)')

# Mostramos el gráfico
plt.show()
