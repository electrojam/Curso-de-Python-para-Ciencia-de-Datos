# %% [markdown]
# <a href="https://colab.research.google.com/github/electrojam/Curso-de-Python-para-Ciencia-de-Datos/blob/main/Clase23_Introducci%C3%B3n_a_Matplotlib_gr%C3%A1fico_de_l%C3%ADneas_y_dispersi%C3%B3n23_32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfico de Líneas plot

# %%
month = np.array(['E', 'F', 'M', 'A', 'MA'])
sales = np.array([20, 25, 30, 28, 35])

# %%
# Configurar el tamaño del gráfico
plt.figure(figsize=(8, 6))

# Crear el gráfico
plt.plot(month, sales, marker='o', color='blue')

# Etiquetar el gráfico
plt.title('Ventas mensuales de un producto')
plt.xlabel('Meses')
plt.ylabel('Ventas en miles de unidades')

# Mostramos el gráfico
plt.show()

# %% [markdown]
# ### Gráfico de dispersión scatter plot

# %%
hours = [2,3,4,5,6,7,8]
exam = [55,60,65,70,75,80,85]

# Configurar el tamaño del gráfico
plt.figure(figsize=(8,6))

# Crear el gráfico
plt.scatter(hours, exam, color='green')

# Etiquetar el gráfico
plt.title('Relación entre horas estudiadas y el puntaje')
plt.xlabel('Horas')
plt.ylabel('Puntaje')

# Mostramos el gráfico
plt.show()
